# %% [markdown]
# ### Importing libraries

# %%
from models import Yolov4
model = Yolov4(weight_path='yolov4.weights',
               class_name_path='class_names/coco_classes.txt')

import pandas as pd
import cv2
import numpy as np
import easyocr
from PIL import Image, ImageDraw
# Out:
# nms iou: 0.413 score: 0.3
# all weights read
# load from yolov4.weights

# %% [markdown]
# ### Loading dataframe from CSV

# %%
features = ['time','frame_name','frame_name_2','lat','lon','hmsl','ggs','gc','hacc','satellite','ping_edge','ping_six','iperf_down','iperf_up','netmode']


df = pd.read_csv('data/2023-01-05_10_56_51.985284_merged.csv', skiprows=2393, nrows=200, header=None, names=features)

# %%
print(df.shape)
df.head()
# Out:
# (300, 15)
#                          time        frame_name  frame_name_2        lat
# 0  2023-01-05 10:58:08.285683  frame_1_2293.jpg           NaN  48.154501  \
# 1  2023-01-05 10:58:08.319377  frame_1_2294.jpg           NaN  48.154501
# 2  2023-01-05 10:58:08.348095  frame_1_2295.jpg           NaN  48.154501
# 3  2023-01-05 10:58:08.383647  frame_1_2296.jpg           NaN  48.154485
# 4  2023-01-05 10:58:08.414204  frame_1_2297.jpg           NaN  48.154485
#
#          lon      hmsl   ggs         gc  hacc  satellite  ping_edge  ping_six
# 0  17.074559  159327.0  1192  129.19606  14.1         44     30.484    36.456  \
# 1  17.074559  159327.0  1192  129.19606  14.1         44     30.484    36.456
# 2  17.074559  159327.0  1192  129.19606  14.1         44     30.484    36.456
# 3  17.074587  159212.3  1155  129.33816  16.1         44     30.484    36.456
# 4  17.074587  159212.3  1155  129.33816  16.1         44     30.484    36.456
#
#    iperf_down  iperf_up netmode
# 0    146532.0   43870.0   5G-NR
# 1    146532.0   43870.0   5G-NR
# 2    146532.0   43870.0   5G-NR
# 3    146532.0   43870.0   5G-NR
# 4    146532.0   43870.0   5G-NR

# %% [markdown]
# ### Image preprocessing functions

# %%
def increase_contrast(image, alpha=1.5, beta=10):
    result = np.zeros(image.shape, dtype=np.uint8)
    
    cv2.convertScaleAbs(image, result, alpha=alpha, beta=beta)
    
    return result

def preprocess_image(image):
    norm_img = np.zeros((image.shape[0], image.shape[1]))
    # Image normalization
    image = cv2.normalize(image, norm_img, 0, 255, cv2.NORM_MINMAX)
    # Increasing contrast for better readability
    image = increase_contrast(image)
    # Removing noise from color image
    image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 15)
    
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Image segmentation
    _, result = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    return result

def is_negative(num):
    return num if num >= 0 else 0

# %% [markdown]
# ### Blurring license plates
# - Detection of cars in the image
# - The use of the model to recognize license plates
# - The use of easyocr for text detection in the image

# %% [markdown]
# ## Todo, vyskusat predspracovat obrazok pred detekciou modelu

# %%
reader = easyocr.Reader(['en'])
model1 = cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')

# Iteration through the dataframe
for index, row in df.iterrows():
    
    file_name = 'img/' + row['frame_name']
    print(file_name)
    
    # Object prediction with YoLo 
    predictions = model.predict(file_name)
    # Filtering only vehicles
    predictions = predictions.loc[(predictions['class_name'].isin(['car', 'bus'])) & (predictions['w'] > 50) & (predictions['h'] > 50)]

    image = cv2.imread(file_name)
    
    # Iterate over individual vehicles
    for idx, car in predictions.iterrows():
        # Cutting out the vehicle from the image
        c_x, c_y, c_h, c_w = car['x1'], car['y1'], car['h'], car['w']
        cropped_image = image[c_y:c_y + c_h, c_x:c_x + c_w] 
        
        # The use of a model to recognize license plates
        plates = model1.detectMultiScale(cropped_image, scaleFactor=1.01, minNeighbors=5, maxSize=(100,100))

        for (x, y, w, h) in plates:
            car_roi = cropped_image[y:y+h, x:x+w]
            blur = cv2.GaussianBlur(car_roi, (25, 25), 0)
            cropped_image[y:y+h, x:x+w] = blur

            image[c_y:c_y + c_h, c_x:c_x + c_w] = cropped_image

        # Car image preprocessing
        preprocessed_image = preprocess_image(cropped_image)
        # Using easyocr to search for text on car image
        result = reader.readtext(preprocessed_image, detail=1, paragraph=False)
        
        if(result):
            crd = result[0][0]
            t_x1, t_y1 = int(is_negative(crd[0][0])), int(is_negative(crd[0][1]))
            t_x2, t_y2 = int(is_negative(crd[2][0])), int(is_negative(crd[2][1]))

            t_w = t_x2 - t_x1
            t_h = t_y2 - t_y1

            main_text_x = c_x + t_x1
            main_text_y = c_y + t_y1

            blur = cv2.GaussianBlur(image[main_text_y:main_text_y + t_h, main_text_x:main_text_x+t_w], (15, 15), 30)
            image[main_text_y:main_text_y + t_h, main_text_x:main_text_x + t_w] = blur 
                
    cv2.imwrite('new/' + row['frame_name'], image)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# img/frame_1_2393.jpg
# 1/1 [==============================] - 0s 461ms/step
# # of bboxes: 10
# img/frame_1_2394.jpg
# 1/1 [==============================] - 0s 470ms/step
# # of bboxes: 11
# img/frame_1_2395.jpg
# 1/1 [==============================] - 0s 463ms/step
# # of bboxes: 9
# img/frame_1_2396.jpg
# 1/1 [==============================] - 1s 523ms/step
# # of bboxes: 9
# img/frame_1_2397.jpg
# 1/1 [==============================] - 1s 502ms/step
# # of bboxes: 11
# img/frame_1_2398.jpg
# 1/1 [==============================] - 1s 568ms/step
# # of bboxes: 10
# img/frame_1_2399.jpg
# 1/1 [==============================] - 1s 544ms/step
# # of bboxes: 10
# img/frame_1_2400.jpg
# 1/1 [==============================] - 0s 495ms/step
# # of bboxes: 10
# img/frame_1_2401.jpg
# 1/1 [==============================] - 0s 475ms/step
# # of bboxes: 11
# img/frame_1_2402.jpg
# 1/1 [==============================] - 0s 480ms/step
# # of bboxes: 12
# img/frame_1_2403.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 14
# img/frame_1_2404.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 11
# img/frame_1_2405.jpg
# 1/1 [==============================] - 1s 767ms/step
# # of bboxes: 11
# img/frame_1_2406.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 9
# img/frame_1_2407.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 14
# img/frame_1_2408.jpg
# 1/1 [==============================] - 1s 515ms/step
# # of bboxes: 14
# img/frame_1_2409.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 11
# img/frame_1_2410.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 10
# img/frame_1_2411.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 13
# img/frame_1_2412.jpg
# 1/1 [==============================] - 1s 517ms/step
# # of bboxes: 9
# img/frame_1_2413.jpg
# 1/1 [==============================] - 1s 539ms/step
# # of bboxes: 14
# img/frame_1_2414.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 19
# img/frame_1_2415.jpg
# 1/1 [==============================] - 1s 703ms/step
# # of bboxes: 10
# img/frame_1_2416.jpg
# 1/1 [==============================] - 1s 516ms/step
# # of bboxes: 11
# img/frame_1_2417.jpg
# 1/1 [==============================] - 1s 500ms/step
# # of bboxes: 10
# img/frame_1_2418.jpg
# 1/1 [==============================] - 1s 500ms/step
# # of bboxes: 14
# img/frame_1_2419.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 12
# img/frame_1_2420.jpg
# 1/1 [==============================] - 1s 511ms/step
# # of bboxes: 13
# img/frame_1_2421.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 15
# img/frame_1_2422.jpg
# 1/1 [==============================] - 1s 516ms/step
# # of bboxes: 9
# img/frame_1_2423.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 14
# img/frame_1_2424.jpg
# 1/1 [==============================] - 1s 609ms/step
# # of bboxes: 15
# img/frame_1_2425.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 9
# img/frame_1_2426.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 11
# img/frame_1_2427.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 10
# img/frame_1_2428.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 8
# img/frame_1_2429.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 10
# img/frame_1_2430.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 12
# img/frame_1_2431.jpg
# 1/1 [==============================] - 1s 625ms/step
# # of bboxes: 11
# img/frame_1_2432.jpg
# 1/1 [==============================] - 1s 578ms/step
# # of bboxes: 12
# img/frame_1_2433.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 12
# img/frame_1_2434.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 10
# img/frame_1_2435.jpg
# 1/1 [==============================] - 1s 797ms/step
# # of bboxes: 9
# img/frame_1_2436.jpg
# 1/1 [==============================] - 1s 659ms/step
# # of bboxes: 11
# img/frame_1_2437.jpg
# 1/1 [==============================] - 1s 611ms/step
# # of bboxes: 10
# img/frame_1_2438.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 14
# img/frame_1_2439.jpg
# 1/1 [==============================] - 1s 548ms/step
# # of bboxes: 10
# img/frame_1_2440.jpg
# 1/1 [==============================] - 1s 610ms/step
# # of bboxes: 15
# img/frame_1_2441.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 11
# img/frame_1_2442.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 9
# img/frame_1_2443.jpg
# 1/1 [==============================] - 1s 548ms/step
# # of bboxes: 8
# img/frame_1_2444.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 11
# img/frame_1_2445.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 13
# img/frame_1_2446.jpg
# 1/1 [==============================] - 1s 580ms/step
# # of bboxes: 12
# img/frame_1_2447.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 16
# img/frame_1_2448.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 12
# img/frame_1_2449.jpg
# 1/1 [==============================] - 1s 579ms/step
# # of bboxes: 12
# img/frame_1_2450.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 11
# img/frame_1_2451.jpg
# 1/1 [==============================] - 1s 532ms/step
# # of bboxes: 11
# img/frame_1_2452.jpg
# 1/1 [==============================] - 1s 611ms/step
# # of bboxes: 15
# img/frame_1_2453.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 10
# img/frame_1_2454.jpg
# 1/1 [==============================] - 1s 595ms/step
# # of bboxes: 11
# img/frame_1_2455.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 11
# img/frame_1_2456.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 11
# img/frame_1_2457.jpg
# 1/1 [==============================] - 1s 579ms/step
# # of bboxes: 12
# img/frame_1_2458.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 11
# img/frame_1_2459.jpg
# 1/1 [==============================] - 1s 625ms/step
# # of bboxes: 10
# img/frame_1_2460.jpg
# 1/1 [==============================] - 1s 595ms/step
# # of bboxes: 8
# img/frame_1_2461.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 9
# img/frame_1_2462.jpg
# 1/1 [==============================] - 1s 625ms/step
# # of bboxes: 10
# img/frame_1_2463.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 8
# img/frame_1_2464.jpg
# 1/1 [==============================] - 1s 625ms/step
# # of bboxes: 8
# img/frame_1_2465.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 7
# img/frame_1_2466.jpg
# 1/1 [==============================] - 1s 690ms/step
# # of bboxes: 14
# img/frame_1_2467.jpg
# 1/1 [==============================] - 1s 578ms/step
# # of bboxes: 9
# img/frame_1_2468.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 11
# img/frame_1_2469.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 9
# img/frame_1_2470.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 11
# img/frame_1_2471.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 6
# img/frame_1_2472.jpg
# 1/1 [==============================] - 1s 578ms/step
# # of bboxes: 8
# img/frame_1_2473.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 9
# img/frame_1_2474.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 10
# img/frame_1_2475.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 8
# img/frame_1_2476.jpg
# 1/1 [==============================] - 1s 544ms/step
# # of bboxes: 12
# img/frame_1_2477.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 11
# img/frame_1_2478.jpg
# 1/1 [==============================] - 1s 581ms/step
# # of bboxes: 12
# img/frame_1_2479.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 10
# img/frame_1_2480.jpg
# 1/1 [==============================] - 1s 580ms/step
# # of bboxes: 10
# img/frame_1_2481.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 10
# img/frame_1_2482.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 11
# img/frame_1_2483.jpg
# 1/1 [==============================] - 1s 516ms/step
# # of bboxes: 12
# img/frame_1_2484.jpg
# 1/1 [==============================] - 0s 484ms/step
# # of bboxes: 10
# img/frame_1_2485.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 9
# img/frame_1_2486.jpg
# 1/1 [==============================] - 1s 750ms/step
# # of bboxes: 10
# img/frame_1_2487.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 12
# img/frame_1_2488.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 8
# img/frame_1_2489.jpg
# 1/1 [==============================] - 1s 580ms/step
# # of bboxes: 8
# img/frame_1_2490.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 13
# img/frame_1_2491.jpg
# 1/1 [==============================] - 1s 579ms/step
# # of bboxes: 10
# img/frame_1_2492.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 7
# img/frame_1_2493.jpg
# 1/1 [==============================] - 1s 716ms/step
# # of bboxes: 9
# img/frame_1_2494.jpg
# 1/1 [==============================] - 1s 651ms/step
# # of bboxes: 10
# img/frame_1_2495.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 11
# img/frame_1_2496.jpg
# 1/1 [==============================] - 1s 656ms/step
# # of bboxes: 11
# img/frame_1_2497.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 10
# img/frame_1_2498.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 10
# img/frame_1_2499.jpg
# 1/1 [==============================] - 1s 532ms/step
# # of bboxes: 10
# img/frame_1_2500.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 10
# img/frame_1_2501.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 13
# img/frame_1_2502.jpg
# 1/1 [==============================] - 1s 563ms/step
# # of bboxes: 10
# img/frame_1_2503.jpg
# 1/1 [==============================] - 1s 625ms/step
# # of bboxes: 12
# img/frame_1_2504.jpg
# 1/1 [==============================] - 1s 548ms/step
# # of bboxes: 10
# img/frame_1_2505.jpg
# 1/1 [==============================] - 1s 533ms/step
# # of bboxes: 10
# img/frame_1_2506.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 9
# img/frame_1_2507.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 9
# img/frame_1_2508.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 7
# img/frame_1_2509.jpg
# 1/1 [==============================] - 1s 596ms/step
# # of bboxes: 6
# img/frame_1_2510.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 5
# img/frame_1_2511.jpg
# 1/1 [==============================] - 1s 546ms/step
# # of bboxes: 6
# img/frame_1_2512.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 7
# img/frame_1_2513.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 6
# img/frame_1_2514.jpg
# 1/1 [==============================] - 1s 641ms/step
# # of bboxes: 5
# img/frame_1_2515.jpg
# 1/1 [==============================] - 1s 674ms/step
# # of bboxes: 6
# img/frame_1_2516.jpg
# 1/1 [==============================] - 1s 562ms/step
# # of bboxes: 5
# img/frame_1_2517.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 6
# img/frame_1_2518.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 5
# img/frame_1_2519.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 7
# img/frame_1_2520.jpg
# 1/1 [==============================] - 1s 547ms/step
# # of bboxes: 7
# img/frame_1_2521.jpg
# 1/1 [==============================] - 1s 534ms/step
# # of bboxes: 5
# img/frame_1_2522.jpg
# 1/1 [==============================] - 1s 551ms/step
# # of bboxes: 6
# img/frame_1_2523.jpg
# 1/1 [==============================] - 1s 531ms/step
# # of bboxes: 6
# img/frame_1_2524.jpg
# 1/1 [==============================] - 1s 569ms/step
# # of bboxes: 4
# img/frame_1_2525.jpg
# 1/1 [==============================] - 1s 553ms/step
# # of bboxes: 5
# img/frame_1_2526.jpg
# 1/1 [==============================] - 1s 532ms/step
# # of bboxes: 6
# img/frame_1_2527.jpg
# 1/1 [==============================] - 1s 605ms/step
# # of bboxes: 10
# img/frame_1_2528.jpg
# 1/1 [==============================] - 1s 564ms/step
# # of bboxes: 8
# img/frame_1_2529.jpg
# 1/1 [==============================] - 1s 515ms/step
# # of bboxes: 10
# img/frame_1_2530.jpg
# 1/1 [==============================] - 1s 572ms/step
# # of bboxes: 6
# img/frame_1_2531.jpg
# 1/1 [==============================] - 1s 579ms/step
# # of bboxes: 7
# img/frame_1_2532.jpg
# 1/1 [==============================] - 1s 573ms/step
# # of bboxes: 7
# img/frame_1_2533.jpg
# 1/1 [==============================] - 1s 525ms/step
# # of bboxes: 6
# img/frame_1_2534.jpg
# 1/1 [==============================] - 1s 639ms/step
# # of bboxes: 8
# img/frame_1_2535.jpg
# 1/1 [==============================] - 1s 626ms/step
# # of bboxes: 12
# img/frame_1_2536.jpg
# 1/1 [==============================] - 1s 588ms/step
# # of bboxes: 14
# img/frame_1_2537.jpg
# 1/1 [==============================] - 1s 594ms/step
# # of bboxes: 8
# img/frame_1_2538.jpg
# 1/1 [==============================] - 1s 623ms/step
# # of bboxes: 10
# img/frame_1_2539.jpg
# 1/1 [==============================] - 1s 580ms/step
# # of bboxes: 6
# img/frame_1_2540.jpg
# 1/1 [==============================] - 1s 626ms/step
# # of bboxes: 11
# img/frame_1_2541.jpg
# 1/1 [==============================] - 1s 713ms/step
# # of bboxes: 9
# img/frame_1_2542.jpg
# 1/1 [==============================] - 1s 595ms/step
# # of bboxes: 10
# img/frame_1_2543.jpg
# 1/1 [==============================] - 1s 608ms/step
# # of bboxes: 11
# img/frame_1_2544.jpg
# 1/1 [==============================] - 1s 598ms/step
# # of bboxes: 16
# img/frame_1_2545.jpg
# 1/1 [==============================] - 1s 629ms/step
# # of bboxes: 17
# img/frame_1_2546.jpg
# 1/1 [==============================] - 1s 603ms/step
# # of bboxes: 14
# img/frame_1_2547.jpg
# 1/1 [==============================] - 1s 595ms/step
# # of bboxes: 9
# img/frame_1_2548.jpg
# 1/1 [==============================] - 1s 596ms/step
# # of bboxes: 11
# img/frame_1_2549.jpg
# 1/1 [==============================] - 1s 596ms/step
# # of bboxes: 12
# img/frame_1_2550.jpg
# 1/1 [==============================] - 1s 632ms/step
# # of bboxes: 10
# img/frame_1_2551.jpg
# 1/1 [==============================] - 1s 595ms/step
# # of bboxes: 11
# img/frame_1_2552.jpg
# 1/1 [==============================] - 1s 597ms/step
# # of bboxes: 11
# img/frame_1_2553.jpg
# 1/1 [==============================] - 1s 614ms/step
# # of bboxes: 8
# img/frame_1_2554.jpg
# 1/1 [==============================] - 1s 589ms/step
# # of bboxes: 12
# img/frame_1_2555.jpg
# 1/1 [==============================] - 1s 596ms/step
# # of bboxes: 13
# img/frame_1_2556.jpg
# 1/1 [==============================] - 1s 678ms/step
# # of bboxes: 12
# img/frame_1_2557.jpg
# 1/1 [==============================] - 1s 580ms/step
# # of bboxes: 11
# img/frame_1_2558.jpg
# 1/1 [==============================] - 1s 584ms/step
# # of bboxes: 10
# img/frame_1_2559.jpg
# 1/1 [==============================] - 1s 597ms/step
# # of bboxes: 12
# img/frame_1_2560.jpg
# 1/1 [==============================] - 1s 593ms/step
# # of bboxes: 13
# img/frame_1_2561.jpg
# 1/1 [==============================] - 1s 646ms/step
# # of bboxes: 13
# img/frame_1_2562.jpg
# 1/1 [==============================] - 0s 486ms/step
# # of bboxes: 12
# img/frame_1_2563.jpg
# 1/1 [==============================] - 1s 611ms/step
# # of bboxes: 10
# img/frame_1_2564.jpg
# 1/1 [==============================] - 1s 609ms/step
# # of bboxes: 15
# img/frame_1_2565.jpg
# 1/1 [==============================] - 1s 645ms/step
# # of bboxes: 12
# img/frame_1_2566.jpg
# 1/1 [==============================] - 1s 588ms/step
# # of bboxes: 11
# img/frame_1_2567.jpg
# 1/1 [==============================] - 1s 609ms/step
# # of bboxes: 13
# img/frame_1_2568.jpg
# 1/1 [==============================] - 1s 596ms/step
# # of bboxes: 11
# img/frame_1_2569.jpg
# 1/1 [==============================] - 1s 656ms/step
# # of bboxes: 11
# img/frame_1_2570.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       8 print(file_name)
#      10 # Object prediction with YoLo
# ---> 11 predictions = model.predict(file_name)
#      12 # Filtering only vehicles
#      13 predictions = predictions.loc[(predictions['class_name'].isin(['car', 'bus'])) & (predictions['w'] > 50) & (predictions['h'] > 50)]
#
# File D:\skola\AIL\blurring_license_plates\models.py:126, in Yolov4.predict(self, img_path, random_color, plot_img, figsize, show_text)
#     124 def predict(self, img_path, random_color=True, plot_img=True, figsize=(10, 10), show_text=True):
#     125     raw_img = cv2.imread(img_path)[:, :, ::-1]
# --> 126     return self.predict_img(raw_img, random_color, plot_img, figsize, show_text)
#
# File D:\skola\AIL\blurring_license_plates\models.py:113, in Yolov4.predict_img(self, raw_img, random_color, plot_img, figsize, show_text, return_output)
#     111 img = self.preprocess_img(raw_img)
#     112 imgs = np.expand_dims(img, axis=0)
# --> 113 pred_output = self.inference_model.predict(imgs)
#     114 detections = get_detection_data(img=raw_img,
#     115                                 model_outputs=pred_output,
#     116                                 class_names=self.class_names)
#     117 #output_img = draw_bbox(raw_img, detections, cmap=self.class_color, random_color=random_color, figsize=figsize,
#     118 #         show_text=show_text, show_img=plot_img)
#     119 #if return_output:
#     120 #   return output_img, detections
#     121 #else:
#
# File d:\skola\ail\env\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\skola\ail\env\lib\site-packages\keras\engine\training.py:2382, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2380 for step in data_handler.steps():
#    2381     callbacks.on_predict_batch_begin(step)
# -> 2382     tmp_batch_outputs = self.predict_function(iterator)
#    2383     if data_handler.should_sync:
#    2384         context.async_wait()
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File d:\skola\ail\env\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
